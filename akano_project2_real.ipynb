# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
filepath = 'C:/Users/HP/Documents/python_one_campus/Assignment/'
filename = 'WA_Fn-UseC_-HR-Employee-Attrition.csv'

df = pd.read_csv(filepath + filename)

# %% [markdown]
# # Exploratory Analysis

# %%
df.head() #checking the data
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
print(df.nunique())
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1470
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome               1349
# MonthlyRate                 1427
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
#removing the columns with one unique value because they are zero-variance predictors 
#they do not contain any information for modeling
#EmployeeCount, Over18, StandardHours
#ea is employee attrittion
ea = df.loc[:, ['Age', 'BusinessTravel', 'DailyRate', 'Department',
       'DistanceFromHome', 'Education', 'EducationField',
       'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
       'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
       'OverTime', 'PercentSalaryHike', 'PerformanceRating',
       'RelationshipSatisfaction', 'StockOptionLevel',
       'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
       'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager', 'Attrition']]

# %%
ea.head() #new dataframe
# Out:
#    Age     BusinessTravel  DailyRate              Department  \
# 0   41      Travel_Rarely       1102                   Sales
# 1   49  Travel_Frequently        279  Research & Development
# 2   37      Travel_Rarely       1373  Research & Development
# 3   33  Travel_Frequently       1392  Research & Development
# 4   27      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 1          2  Life Sciences               1
# 1                 8          1  Life Sciences               2
# 2                 2          2          Other               4
# 3                 3          4  Life Sciences               5
# 4                 2          1        Medical               7
#
#    EnvironmentSatisfaction  Gender  ...  RelationshipSatisfaction  \
# 0                        2  Female  ...                         1
# 1                        3    Male  ...                         4
# ...

# %%
#To show data distribution
ea.hist()
plt.gcf().set_size_inches(20,20)
plt.show()

# %%
ea.isna().sum() #to check for missing values
# Out:
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# ...

# %%
ea.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   BusinessTravel            1470 non-null   object
#  2   DailyRate                 1470 non-null   int64
#  3   Department                1470 non-null   object
#  4   DistanceFromHome          1470 non-null   int64
#  5   Education                 1470 non-null   int64
#  6   EducationField            1470 non-null   object
#  7   EmployeeNumber            1470 non-null   int64
#  8   EnvironmentSatisfaction   1470 non-null   int64
#  9   Gender                    1470 non-null   object
#  10  HourlyRate                1470 non-null   int64
#  11  JobInvolvement            1470 non-null   int64
#  12  JobLevel                  1470 non-null   int64
#  13  JobRole                   1470 non-null   object
# ...

# %%
#some columns have object as their datatype, they need to be changed to category
ea['BusinessTravel'] = ea['BusinessTravel'].astype('category')
ea['Department'] = ea['Department'].astype('category')
ea['EducationField'] = ea['EducationField'].astype('category')
ea['Gender'] = ea['Gender'].astype('category')
ea['JobRole'] = ea['JobRole'].astype('category')
ea['MaritalStatus'] = ea['MaritalStatus'].astype('category')
ea['OverTime'] = ea['OverTime'].astype('category')
ea['Attrition'] = ea['Attrition'].astype('category')

# %%
#categorical data encoding 
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
# Assigning numerical values and storing in another column


ea['BusinessTravel'] = le.fit_transform(ea['BusinessTravel'])
ea['Department'] =le.fit_transform(ea['Department'])
ea['EducationField'] =le.fit_transform(ea['EducationField'])
ea['Gender'] =le.fit_transform(ea['Gender'])
ea['JobRole'] =le.fit_transform(ea['JobRole'])
ea['MaritalStatus'] =le.fit_transform(ea['MaritalStatus'])
ea['OverTime'] =le.fit_transform(ea['OverTime'])
ea['Attrition'] =le.fit_transform(ea['Attrition'])

# %%
dfEncoded = ea

# %%
#putting Age column as the last column to make it easy for identification 
#as the output variable for analysis
#eAge is employee age
eAge = dfEncoded.loc[:, ['BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 
        'Education',
       'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition','Age']]

# %%
eAge.head()
# Out:
#    BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0               2       1102           2                 1          2
# 1               1        279           1                 8          1
# 2               2       1373           1                 2          2
# 3               1       1392           1                 3          4
# 4               2        591           1                 2          1
#
#    EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0               1               1                        2       0
# 1               1               2                        3       1
# 2               4               4                        4       1
# 3               1               5                        4       0
# 4               3               7                        1       1
#
#    HourlyRate  ...  StockOptionLevel  TotalWorkingYears  \
# 0          94  ...                 0                  8
# ...

# %%
eAge.columns
# Out:
# Index(['BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition', 'Age'],
#       dtype='object')

# %%
# Rescale data (between 0 and 1)
from pandas import read_csv
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler


array = eAge.values
# separate array into input and output components
#X is the predictor variable
#Y is the outcome variable
X = array[:,0:31]
Y = array[:,31]
demo = MinMaxScaler(feature_range=(0, 1))
rescaledX = demo.fit_transform(X)
# summarize transformed data
set_printoptions(precision=3)

print(rescaledX[0:5,:])
# Out:
# [[1.000e+00 7.158e-01 1.000e+00 0.000e+00 2.500e-01 2.000e-01 0.000e+00
#   3.333e-01 0.000e+00 9.143e-01 6.667e-01 2.500e-01 8.750e-01 1.000e+00
#   1.000e+00 2.625e-01 6.981e-01 8.889e-01 1.000e+00 0.000e+00 0.000e+00
#   0.000e+00 0.000e+00 2.000e-01 0.000e+00 0.000e+00 1.500e-01 2.222e-01
#   0.000e+00 2.941e-01 1.000e+00]
#  [5.000e-01 1.267e-01 5.000e-01 2.500e-01 0.000e+00 2.000e-01 4.838e-04
#   6.667e-01 1.000e+00 4.429e-01 3.333e-01 2.500e-01 7.500e-01 3.333e-01
#   5.000e-01 2.170e-01 9.160e-01 1.111e-01 0.000e+00 8.571e-01 1.000e+00
#   1.000e+00 3.333e-01 2.500e-01 5.000e-01 6.667e-01 2.500e-01 3.889e-01
#   6.667e-02 4.118e-01 0.000e+00]
#  [1.000e+00 9.098e-01 5.000e-01 3.571e-02 2.500e-01 8.000e-01 1.451e-03
#   1.000e+00 1.000e+00 8.857e-01 3.333e-01 0.000e+00 2.500e-01 6.667e-01
#   1.000e+00 5.692e-02 1.213e-02 6.667e-01 1.000e+00 2.857e-01 0.000e+00
#   3.333e-01 0.000e+00 1.750e-01 5.000e-01 6.667e-01 0.000e+00 0.000e+00
#   0.000e+00 0.000e+00 1.000e+00]
# ...

# %%
eAgeRescaled = pd.DataFrame(rescaledX)
eAgeRescaled.columns = ['BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education',
       'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition']
eAgeRescaled['Age'] = eAge['Age']
eAgeRescaled
# Out:
#       BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0                1.0   0.715820         1.0          0.000000       0.25
# 1                0.5   0.126700         0.5          0.250000       0.00
# 2                1.0   0.909807         0.5          0.035714       0.25
# 3                0.5   0.923407         0.5          0.071429       0.75
# 4                1.0   0.350036         0.5          0.035714       0.00
# ...              ...        ...         ...               ...        ...
# 1465             0.5   0.559771         0.5          0.785714       0.25
# 1466             1.0   0.365784         0.5          0.178571       0.00
# 1467             1.0   0.037938         0.5          0.107143       0.50
# 1468             0.5   0.659270         1.0          0.035714       0.50
# 1469             1.0   0.376521         0.5          0.250000       0.50
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# ...

# %%
eAgeRescaled.describe()
# Out:
#        BusinessTravel    DailyRate   Department  DistanceFromHome  \
# count     1470.000000  1470.000000  1470.000000       1470.000000
# mean         0.803741     0.501421     0.630272          0.292590
# std          0.332727     0.288840     0.263896          0.289531
# min          0.000000     0.000000     0.000000          0.000000
# 25%          0.500000     0.259843     0.500000          0.035714
# 50%          1.000000     0.501074     0.500000          0.214286
# 75%          1.000000     0.755190     1.000000          0.464286
# max          1.000000     1.000000     1.000000          1.000000
#
#          Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# count  1470.000000     1470.000000     1470.000000              1470.000000
# mean      0.478231        0.449524        0.495339                 0.573923
# std       0.256041        0.266274        0.291255                 0.364361
# ...

# %%
eAge = eAgeRescaled

# %%
# Normalize data (length of 1)
from sklearn.preprocessing import Normalizer
from pandas import read_csv
from numpy import set_printoptions
 
# separate array into input and output components
array = eAge.values
X = array[:,0:31]
Y = array[:,31]
scaler = Normalizer().fit(X)
normalizedX = scaler.transform(X)
# summarize transformed data
set_printoptions(precision=5)
print(normalizedX[0:5,:])
# Out:
# [[3.10398e-01 2.22189e-01 3.10398e-01 0.00000e+00 7.75995e-02 6.20796e-02
#   0.00000e+00 1.03466e-01 0.00000e+00 2.83792e-01 2.06932e-01 7.75995e-02
#   2.71598e-01 3.10398e-01 3.10398e-01 8.14651e-02 2.16674e-01 2.75909e-01
#   3.10398e-01 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00 6.20796e-02
#   0.00000e+00 0.00000e+00 4.65597e-02 6.89773e-02 0.00000e+00 9.12935e-02
#   3.10398e-01]
#  [1.74127e-01 4.41238e-02 1.74127e-01 8.70635e-02 0.00000e+00 6.96508e-02
#   1.68483e-04 2.32169e-01 3.48254e-01 1.54227e-01 1.16085e-01 8.70635e-02
#   2.61191e-01 1.16085e-01 1.74127e-01 7.55743e-02 3.19001e-01 3.86949e-02
#   0.00000e+00 2.98504e-01 3.48254e-01 3.48254e-01 1.16085e-01 8.70635e-02
#   1.74127e-01 2.32169e-01 8.70635e-02 1.35432e-01 2.32169e-02 1.43399e-01
#   0.00000e+00]
#  [3.07879e-01 2.80110e-01 1.53939e-01 1.09957e-02 7.69697e-02 2.46303e-01
#   4.46849e-04 3.07879e-01 3.07879e-01 2.72693e-01 1.02626e-01 0.00000e+00
# ...

# %%
eAgeNormalized = pd.DataFrame(rescaledX)
eAgeNormalized.columns = ['BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education',
       'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition']
eAgeNormalized['Age'] = eAge['Age']
eAgeNormalized
# Out:
#       BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0                1.0   0.715820         1.0          0.000000       0.25
# 1                0.5   0.126700         0.5          0.250000       0.00
# 2                1.0   0.909807         0.5          0.035714       0.25
# 3                0.5   0.923407         0.5          0.071429       0.75
# 4                1.0   0.350036         0.5          0.035714       0.00
# ...              ...        ...         ...               ...        ...
# 1465             0.5   0.559771         0.5          0.785714       0.25
# 1466             1.0   0.365784         0.5          0.178571       0.00
# 1467             1.0   0.037938         0.5          0.107143       0.50
# 1468             0.5   0.659270         1.0          0.035714       0.50
# 1469             1.0   0.376521         0.5          0.250000       0.50
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# ...

# %%
eAge = eAgeNormalized

# %%
eAge.describe()
# Out:
#        BusinessTravel    DailyRate   Department  DistanceFromHome  \
# count     1470.000000  1470.000000  1470.000000       1470.000000
# mean         0.803741     0.501421     0.630272          0.292590
# std          0.332727     0.288840     0.263896          0.289531
# min          0.000000     0.000000     0.000000          0.000000
# 25%          0.500000     0.259843     0.500000          0.035714
# 50%          1.000000     0.501074     0.500000          0.214286
# 75%          1.000000     0.755190     1.000000          0.464286
# max          1.000000     1.000000     1.000000          1.000000
#
#          Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# count  1470.000000     1470.000000     1470.000000              1470.000000
# mean      0.478231        0.449524        0.495339                 0.573923
# std       0.256041        0.266274        0.291255                 0.364361
# ...

# %%
eAge.head()
# Out:
#    BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0             1.0   0.715820         1.0          0.000000       0.25
# 1             0.5   0.126700         0.5          0.250000       0.00
# 2             1.0   0.909807         0.5          0.035714       0.25
# 3             0.5   0.923407         0.5          0.071429       0.75
# 4             1.0   0.350036         0.5          0.035714       0.00
#
#    EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 0             0.2        0.000000                 0.333333     0.0
# 1             0.2        0.000484                 0.666667     1.0
# 2             0.8        0.001451                 1.000000     1.0
# 3             0.2        0.001935                 1.000000     0.0
# 4             0.6        0.002903                 0.000000     1.0
#
#    HourlyRate  ...  StockOptionLevel  TotalWorkingYears  \
# 0    0.914286  ...          0.000000              0.200
# ...

# %%
#to identify which attributes (and combination of attributes)contribute the most to predicting the target attribute
#Feature Extraction with RFE

from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load data

array = eAge.values
X = array[:,0:31]
Y = array[:,31]
# feature extraction
model = LogisticRegression(max_iter = 500)
rfe = RFE(model, 18)
fit = rfe.fit(X, Y)
print("Num Features: {}".format(fit.n_features_)) 
print("Selected Features: {}".format(fit.support_))
print("Feature Ranking: {}".format(fit.ranking_))
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_features_to_select=18 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "
# Num Features: 18
# Selected Features: [ True False  True False  True False  True False False False  True  True
#   True False  True  True  True  True False False False  True False  True
#  False  True False  True  True  True  True]
# Feature Ranking: [ 1  4  1  8  1  6  1 13  5  9  1  1  1 11  1  1  1  1 12 10 14  1  2  1
#   7  1  3  1  1  1  1]

# %%
viableCols = []
rankList = list(fit.ranking_)
columnList = ['BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education',
       'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition','Age']
for rank, col in zip(rankList, columnList):
    idx = rank
    colname = col
    if idx == 1:
        viableCols.append(colname)
print(viableCols)
# Out:
# ['BusinessTravel', 'Department', 'Education', 'EmployeeNumber', 'JobInvolvement', 'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'RelationshipSatisfaction', 'TotalWorkingYears', 'WorkLifeBalance', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition']

# %%
eAgeModel = eAge.loc[:, viableCols] #eAgeModel is the employee age data that will be used for modelling
eAgeModel
# Out:
#       BusinessTravel  Department  Education  EmployeeNumber  JobInvolvement  \
# 0                1.0         1.0       0.25        0.000000        0.666667
# 1                0.5         0.5       0.00        0.000484        0.333333
# 2                1.0         0.5       0.25        0.001451        0.333333
# 3                0.5         0.5       0.75        0.001935        0.666667
# 4                1.0         0.5       0.00        0.002903        0.666667
# ...              ...         ...        ...             ...             ...
# 1465             0.5         0.5       0.25        0.996613        1.000000
# 1466             1.0         0.5       0.00        0.997097        0.333333
# 1467             1.0         0.5       0.50        0.998065        1.000000
# 1468             0.5         1.0       0.50        0.998549        0.333333
# 1469             1.0         0.5       0.50        1.000000        1.000000
#
# ...

# %%
eAgeModel['Age'] = eAge['Age']
eAgeModel
# Out:
#       BusinessTravel  Department  Education  EmployeeNumber  JobInvolvement  \
# 0                1.0         1.0       0.25        0.000000        0.666667
# 1                0.5         0.5       0.00        0.000484        0.333333
# 2                1.0         0.5       0.25        0.001451        0.333333
# 3                0.5         0.5       0.75        0.001935        0.666667
# 4                1.0         0.5       0.00        0.002903        0.666667
# ...              ...         ...        ...             ...             ...
# 1465             0.5         0.5       0.25        0.996613        1.000000
# 1466             1.0         0.5       0.00        0.997097        0.333333
# 1467             1.0         0.5       0.50        0.998065        1.000000
# 1468             0.5         1.0       0.50        0.998549        0.333333
# 1469             1.0         0.5       0.50        1.000000        1.000000
#
# ...

# %% [markdown]
# # Regression algorithms to predict the age of employees leaving the firm

# %%
# Linear Regression
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression

array = eAgeModel.values

X = array[:,0:18]
Y = array[:,18]
kfold = KFold(n_splits=10, random_state=7, shuffle = True)
model = LinearRegression()
scoring = 'neg_mean_squared_error'
results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print(results.mean())
# Out:
# -41.646798794070435

# %%
# Lasso Regression
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Lasso

array = eAgeModel.values
X = array[:,0:18]
Y = array[:,18]
kfold = KFold(n_splits=10, random_state=7, shuffle = True)
model = Lasso()
scoring = 'neg_mean_squared_error'
results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print(results.mean())
# Out:
# -71.94709308788553

# %%
# ElasticNet Regression
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import ElasticNet

array = eAgeModel.values
X = array[:,0:18]
Y = array[:,18]
kfold = KFold(n_splits=10, random_state=7, shuffle = True)
model = ElasticNet()
scoring = 'neg_mean_squared_error'
results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print(results.mean())
# Out:
# -75.68337458204027

# %%
# KNN Regression
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsRegressor

array = eAgeModel.values
X = array[:,0:18]
Y = array[:,18]
kfold = KFold(n_splits=10, random_state=7, shuffle = True)
model = KNeighborsRegressor()
scoring = 'neg_mean_squared_error'
results = cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
print(results.mean())
# Out:
# -61.06560544217687

# %% [markdown]
# #  Classification algorithms to predict the attrition of employees

# %%
dfEncoded = ea #ea is employee attriton data

# %%
ea.describe()
# Out:
#                Age  BusinessTravel    DailyRate   Department  \
# count  1470.000000     1470.000000  1470.000000  1470.000000
# mean     36.923810        1.607483   802.485714     1.260544
# std       9.135373        0.665455   403.509100     0.527792
# min      18.000000        0.000000   102.000000     0.000000
# 25%      30.000000        1.000000   465.000000     1.000000
# 50%      36.000000        2.000000   802.000000     1.000000
# 75%      43.000000        2.000000  1157.000000     2.000000
# max      60.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeNumber  \
# count       1470.000000  1470.000000     1470.000000     1470.000000
# mean           9.192517     2.912925        2.247619     1024.865306
# std            8.106864     1.024165        1.331369      602.024335
# min            1.000000     1.000000        0.000000        1.000000
# ...

# %%
ea.head()
# Out:
#    Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 0   41               2       1102           2                 1          2
# 1   49               1        279           1                 8          1
# 2   37               2       1373           1                 2          2
# 3   33               1       1392           1                 3          4
# 4   27               2        591           1                 2          1
#
#    EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  ...  \
# 0               1               1                        2       0  ...
# 1               1               2                        3       1  ...
# 2               4               4                        4       1  ...
# 3               1               5                        4       0  ...
# 4               3               7                        1       1  ...
#
#    RelationshipSatisfaction  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
ea.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
# Rescale data (between 0 and 1) with attrition as Y
from pandas import read_csv
from numpy import set_printoptions
from sklearn.preprocessing import MinMaxScaler

array = ea.values
# separate array into input and output components
#X is the predictor variable
#Y is the outcome variable
X = array[:,0:31]
Y = array[:,31]
demo = MinMaxScaler(feature_range=(0, 1))
rescaledX = demo.fit_transform(X)
# summarize transformed data
set_printoptions(precision=3)

print(rescaledX[0:5,:])
# Out:
# [[5.476e-01 1.000e+00 7.158e-01 1.000e+00 0.000e+00 2.500e-01 2.000e-01
#   0.000e+00 3.333e-01 0.000e+00 9.143e-01 6.667e-01 2.500e-01 8.750e-01
#   1.000e+00 1.000e+00 2.625e-01 6.981e-01 8.889e-01 1.000e+00 0.000e+00
#   0.000e+00 0.000e+00 0.000e+00 2.000e-01 0.000e+00 0.000e+00 1.500e-01
#   2.222e-01 0.000e+00 2.941e-01]
#  [7.381e-01 5.000e-01 1.267e-01 5.000e-01 2.500e-01 0.000e+00 2.000e-01
#   4.838e-04 6.667e-01 1.000e+00 4.429e-01 3.333e-01 2.500e-01 7.500e-01
#   3.333e-01 5.000e-01 2.170e-01 9.160e-01 1.111e-01 0.000e+00 8.571e-01
#   1.000e+00 1.000e+00 3.333e-01 2.500e-01 5.000e-01 6.667e-01 2.500e-01
#   3.889e-01 6.667e-02 4.118e-01]
#  [4.524e-01 1.000e+00 9.098e-01 5.000e-01 3.571e-02 2.500e-01 8.000e-01
#   1.451e-03 1.000e+00 1.000e+00 8.857e-01 3.333e-01 0.000e+00 2.500e-01
#   6.667e-01 1.000e+00 5.692e-02 1.213e-02 6.667e-01 1.000e+00 2.857e-01
#   0.000e+00 3.333e-01 0.000e+00 1.750e-01 5.000e-01 6.667e-01 0.000e+00
#   0.000e+00 0.000e+00 0.000e+00]
# ...

# %%
eaRescaled = pd.DataFrame(rescaledX)
eaRescaled.columns = ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education',
       'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']
eaRescaled['Attrition'] = ea['Attrition']
eaRescaled
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.547619             1.0   0.715820         1.0          0.000000
# 1     0.738095             0.5   0.126700         0.5          0.250000
# 2     0.452381             1.0   0.909807         0.5          0.035714
# 3     0.357143             0.5   0.923407         0.5          0.071429
# 4     0.214286             1.0   0.350036         0.5          0.035714
# ...        ...             ...        ...         ...               ...
# 1465  0.428571             0.5   0.559771         0.5          0.785714
# 1466  0.500000             1.0   0.365784         0.5          0.178571
# 1467  0.214286             1.0   0.037938         0.5          0.107143
# 1468  0.738095             0.5   0.659270         1.0          0.035714
# 1469  0.380952             1.0   0.376521         0.5          0.250000
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# ...

# %%
eaRescaled.describe()
# Out:
#                Age  BusinessTravel    DailyRate   Department  \
# count  1470.000000     1470.000000  1470.000000  1470.000000
# mean      0.450567        0.803741     0.501421     0.630272
# std       0.217509        0.332727     0.288840     0.263896
# min       0.000000        0.000000     0.000000     0.000000
# 25%       0.285714        0.500000     0.259843     0.500000
# 50%       0.428571        1.000000     0.501074     0.500000
# 75%       0.595238        1.000000     0.755190     1.000000
# max       1.000000        1.000000     1.000000     1.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeNumber  \
# count       1470.000000  1470.000000     1470.000000     1470.000000
# mean           0.292590     0.478231        0.449524        0.495339
# std            0.289531     0.256041        0.266274        0.291255
# min            0.000000     0.000000        0.000000        0.000000
# ...

# %%
ea = eaRescaled

# %%
# Normalize data (length of 1)
from sklearn.preprocessing import Normalizer
from pandas import read_csv
from numpy import set_printoptions
 
# separate array into input and output components
array = ea.values
X = array[:,0:31]
Y = array[:,31]
scaler = Normalizer().fit(X)
normalizedX = scaler.transform(X)
# summarize transformed data
set_printoptions(precision=5)
print(normalizedX[0:5,:])
# Out:
# [[1.76020e-01 3.21428e-01 2.30084e-01 3.21428e-01 0.00000e+00 8.03570e-02
#   6.42856e-02 0.00000e+00 1.07143e-01 0.00000e+00 2.93877e-01 2.14285e-01
#   8.03570e-02 2.81249e-01 3.21428e-01 3.21428e-01 8.43600e-02 2.24374e-01
#   2.85714e-01 3.21428e-01 0.00000e+00 0.00000e+00 0.00000e+00 0.00000e+00
#   6.42856e-02 0.00000e+00 0.00000e+00 4.82142e-02 7.14284e-02 0.00000e+00
#   9.45376e-02]
#  [2.48952e-01 1.68645e-01 4.27346e-02 1.68645e-01 8.43224e-02 0.00000e+00
#   6.74579e-02 1.63178e-04 2.24860e-01 3.37290e-01 1.49371e-01 1.12430e-01
#   8.43224e-02 2.52967e-01 1.12430e-01 1.68645e-01 7.31949e-02 3.08958e-01
#   3.74766e-02 0.00000e+00 2.89105e-01 3.37290e-01 3.37290e-01 1.12430e-01
#   8.43224e-02 1.68645e-01 2.24860e-01 8.43224e-02 1.31168e-01 2.24860e-02
#   1.38884e-01]
#  [1.44845e-01 3.20185e-01 2.91306e-01 1.60092e-01 1.14352e-02 8.00462e-02
#   2.56148e-01 4.64709e-04 3.20185e-01 3.20185e-01 2.83592e-01 1.06728e-01
# ...

# %%
eaNormalized = pd.DataFrame(normalizedX)
eaNormalized.columns = ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education',
       'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager']
eaNormalized['Attrition'] = ea['Attrition']
eaNormalized
# Out:
#            Age  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0     0.176020        0.321428   0.230084    0.321428          0.000000
# 1     0.248952        0.168645   0.042735    0.168645          0.084322
# 2     0.144845        0.320185   0.291306    0.160092          0.011435
# 3     0.125681        0.175953   0.324953    0.175953          0.025136
# 4     0.081546        0.380547   0.133205    0.190273          0.013591
# ...        ...             ...        ...         ...               ...
# 1465  0.143500        0.167417   0.187430    0.167417          0.263083
# 1466  0.172268        0.344537   0.126026    0.172268          0.061524
# 1467  0.070222        0.327704   0.012433    0.163852          0.035111
# 1468  0.237796        0.161087   0.212400    0.322175          0.011506
# 1469  0.132925        0.348929   0.131379    0.174464          0.087232
#
#       Education  EducationField  EmployeeNumber  EnvironmentSatisfaction  \
# ...

# %%
ea = eaNormalized

# %%
ea.describe()
# Out:
#                Age  BusinessTravel    DailyRate   Department  \
# count  1470.000000     1470.000000  1470.000000  1470.000000
# mean      0.149404        0.269174     0.167707     0.210014
# std       0.067989        0.113565     0.096300     0.084025
# min       0.000000        0.000000     0.000000     0.000000
# 25%       0.099589        0.188136     0.089458     0.162288
# 50%       0.143253        0.312180     0.165647     0.179955
# 75%       0.195194        0.343330     0.251598     0.296860
# max       0.346334        0.479337     0.416890     0.408828
#
#        DistanceFromHome    Education  EducationField  EmployeeNumber  \
# count       1470.000000  1470.000000     1470.000000     1470.000000
# mean           0.097389     0.159918        0.150482        0.166102
# std            0.095689     0.085229        0.089051        0.097814
# min            0.000000     0.000000        0.000000        0.000000
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import set_option
data = ea
set_option('display.width', 100)

plt.figure(figsize=(16,10))

sns.heatmap(data.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
#to identify which attributes (and combination of attributes)contribute the most to predicting the target attribute
# Feature Extraction with RFE
from pandas import read_csv
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
# load data

array = ea.values
X = array[:,0:31]
Y = array[:,31]
# feature extraction
model = LogisticRegression()
rfe = RFE(model, 18)
fit = rfe.fit(X, Y)
print("Num Features: {}".format(fit.n_features_)) 
print("Selected Features: {}".format(fit.support_))
print("Feature Ranking: {}".format(fit.ranking_))
# Out:
# Num Features: 18
# Selected Features: [ True False False  True  True False False False  True False False  True
#   True False  True  True  True False  True  True False False  True  True
#   True False  True False  True  True  True]
# Feature Ranking: [ 1 11  3  1  1 12  8 10  1  6  7  1  1 14  1  1  1  9  1  1  4 13  1  1
#   1  2  1  5  1  1  1]
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:70: FutureWarning: Pass n_features_to_select=18 as keyword args. From version 1.0 (renaming of 0.25) passing these as positional arguments will result in an error
#   warnings.warn(f"Pass {args_msg} as keyword args. From version "

# %%
ea.columns
# Out:
# Index(['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education',
#        'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition'],
#       dtype='object')

# %%
viableCols = []
rankList = list(fit.ranking_)
columnList = ['Age', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'Education',
       'EducationField', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
       'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
       'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
       'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
       'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
       'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Attrition']
for rank, col in zip(rankList, columnList):
    idx = rank
    colname = col
    if idx == 1:
        viableCols.append(colname)
print(viableCols)
# Out:
# ['Age', 'Department', 'DistanceFromHome', 'EnvironmentSatisfaction', 'JobInvolvement', 'JobLevel', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'NumCompaniesWorked', 'OverTime', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'WorkLifeBalance', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager']

# %%
eaModel = ea.loc[:, viableCols] #eaModel is the employee attiriton data that will be used for modelling
eaModel
# Out:
#            Age  Department  DistanceFromHome  EnvironmentSatisfaction  JobInvolvement  JobLevel  \
# 0     0.176020    0.321428          0.000000                 0.107143        0.214285  0.080357
# 1     0.248952    0.168645          0.084322                 0.224860        0.112430  0.084322
# 2     0.144845    0.160092          0.011435                 0.320185        0.106728  0.000000
# 3     0.125681    0.175953          0.025136                 0.351906        0.234604  0.000000
# 4     0.081546    0.190273          0.013591                 0.000000        0.253698  0.000000
# ...        ...         ...               ...                      ...             ...       ...
# 1465  0.143500    0.167417          0.263083                 0.223222        0.334833  0.083708
# 1466  0.172268    0.172268          0.061524                 0.344537        0.114846  0.172268
# 1467  0.070222    0.163852          0.035111                 0.109235        0.327704  0.081926
# ...

# %%
eaModel['Attrition'] = ea['Attrition']
eaModel
# Out:
#            Age  Department  DistanceFromHome  EnvironmentSatisfaction  JobInvolvement  JobLevel  \
# 0     0.176020    0.321428          0.000000                 0.107143        0.214285  0.080357
# 1     0.248952    0.168645          0.084322                 0.224860        0.112430  0.084322
# 2     0.144845    0.160092          0.011435                 0.320185        0.106728  0.000000
# 3     0.125681    0.175953          0.025136                 0.351906        0.234604  0.000000
# 4     0.081546    0.190273          0.013591                 0.000000        0.253698  0.000000
# ...        ...         ...               ...                      ...             ...       ...
# 1465  0.143500    0.167417          0.263083                 0.223222        0.334833  0.083708
# 1466  0.172268    0.172268          0.061524                 0.344537        0.114846  0.172268
# 1467  0.070222    0.163852          0.035111                 0.109235        0.327704  0.081926
# ...

# %% [markdown]
# # Classification Models for Attrition

# %%
# Logistic Regression Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
#from sklearn.metrics import confusion_matrix
from sklearn.linear_model import LogisticRegression



array = eaModel.values # Converting input data to arrays
X = array[:,0:18] # Algorithms ONLY accept Arrays
Y = array[:,18]


num_folds = 10
kfold = KFold(n_splits=num_folds)#, shuffle = True, random_state=7)
model = LogisticRegression(max_iter = 500)

results = cross_val_score(model, X, Y, cv=kfold) # epochs

score = np.mean(results)
print(results)
print(results.mean())
# Out:
# [0.84354 0.87075 0.87075 0.88435 0.83673 0.82313 0.85714 0.87075 0.84354
#  0.89796]
# 0.8598639455782312

# %%
# LDA Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

array = eaModel.values
X = array[:,0:18]
Y = array[:,18]
num_folds = 10
kfold = KFold(n_splits=10,shuffle = True, random_state=7)
model = LinearDiscriminantAnalysis()
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.8727891156462585

# %%
#KNN Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

array = eaModel.values
X = array[:,0:18]
Y = array[:,18]
num_folds = 10
kfold = KFold(n_splits=10, random_state=7, shuffle = True)
model = KNeighborsClassifier()
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.8435374149659864

# %%
# Gaussian Naive Bayes Classification
from pandas import read_csv
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.naive_bayes import GaussianNB

array = eaModel.values
X = array[:,0:18]
Y = array[:,18]
kfold = KFold(n_splits=10, random_state=7, shuffle=True)
model = GaussianNB()
results = cross_val_score(model, X, Y, cv=kfold)
print(results.mean())
# Out:
# 0.7993197278911565

# %%
'''LDA was the best in predictibg the attrition rate because 
 the data had a Gaussian distribution for the numerical input variables
 and there was no multicolinearity between the data
 Logistic regression also performed well is prediction 
 because the value of the target variable is categorical in nature. 
and has binary output which is either a 0 or 1.
KNN was also used because data is clearly labeled (0/1) 
and there was no missing data or outliers
Naive Bayes didn't perform as the others because of its
assumption of independence among predictors 
i.e the presence of a particular feature in a class 
is unrelated to the presence of any other feature'''
# Out:
# "LDA was the best in predictibg the attrition rate because \n the data had a Gaussian distribution for the numerical input variables\n and there was no multicolinearity between the data\n Logistic regression also performed well is prediction \n because the value of the target variable is categorical in nature. \nand has binary output which is either a 0 or 1.\nKNN was also used because data is clearly labeled (0/1) \nand there was no missing data or outliers\nNaive Bayes didn't perform as the others because of its\nassumption of independence among predictors \ni.e the presence of a particular feature in a class \nis unrelated to the presence of any other feature"
